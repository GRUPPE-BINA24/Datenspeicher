# %% [markdown]
# <a href="https://colab.research.google.com/github/GRUPPE-BINA24/Datenspeicher/blob/main/Semesterarbeit_BINA_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Hello World")
# Out:
# Hello World

# %%
import pandas as pd
Set1 = pd.read_excel("sample_data/Durschn.Mietpreis_NachBaujahr.xlsx")
Set1.head()
# Out:
#   Durchschnittlicher Mietpreis1) in Franken nach Bauperiode und Kanton   \
# 0                                               2022
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                            Schweiz
#
#                        Unnamed: 1                           Unnamed: 2  \
# 0                             NaN                                  NaN
# 1                      Bauperiode                                  NaN
# 2                           Total                                  NaN
# 3  Durch-schnittlicher Mietpreis   Vertrauens-intervall : \n± (in Fr.)
# 4                            1412                                    3
#
#                        Unnamed: 3                           Unnamed: 4  \
# 0                             NaN                                  NaN
# ...
