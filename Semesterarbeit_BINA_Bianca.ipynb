# %% [markdown]
# <a href="https://colab.research.google.com/github/GRUPPE-BINA24/Datenspeicher/blob/main/Semesterarbeit_BINA_Bianca.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Hier werden die Daten von Github eingelesen

# %%
import pandas as pd
Dataset = ("https://raw.githubusercontent.com/GRUPPE-BINA24/Datenspeicher/main/Wetterdaten_je-d.xlsx")
df=pd.read_excel(Dataset)
df.head()
# Out:
#   Klimadaten: Sonnenscheindauer                               Unnamed: 1  \
# 0                           NaN                                      NaN
# 1                           NaN                                      NaN
# 2                          Jahr  Jährliche Sonnenscheindauer, in Stunden
# 3                           NaN                                      NaN
# 4                           NaN                       Basel-Binningen 1)
#
#              Unnamed: 2 Unnamed: 3        Unnamed: 4     Unnamed: 5  \
# 0                   NaN        NaN               NaN            NaN
# 1                   NaN        NaN               NaN            NaN
# 2                   NaN        NaN               NaN            NaN
# 3                   NaN        NaN               NaN            NaN
# 4  Bern-Zollikofen 1,2)   Davos 1)  Genf-Cointrin 1)  Locarno-Monti
#
#   Unnamed: 6 Unnamed: 7    Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 0        NaN        NaN           NaN        NaN         NaN         NaN
# 1        NaN        NaN           NaN        NaN         NaN         NaN
# 2        NaN        NaN           NaN        NaN         NaN         NaN
# 3        NaN        NaN           NaN        NaN         NaN         NaN
# 4  Lugano 1)  Luzern 1)  Neuenburg 1)  Säntis 1)  Samedan 1)   Sitten 1)
#
#   Unnamed: 12       T 02.03.03.02
# 0         NaN                 NaN
# 1         NaN                 NaN
# 2         NaN                 NaN
# 3         NaN                 NaN
# 4  St. Gallen  Zürich-Fluntern 1)

# %%
df.tail()
# Out:
#                          Klimadaten: Sonnenscheindauer Unnamed: 1 Unnamed: 2  \
# 105  werden deshalb homogenisierte Daten verwendet,...        NaN        NaN
# 106     2) Bis 2005 Messungen in Bern-Liebefeld, 565 m        NaN        NaN
# 107                               Quelle: MeteoSchweiz        NaN        NaN
# 108                                         © BFS 2024        NaN        NaN
# 109                        Letzte Änderung: 22.02.2024        NaN        NaN
#
#     Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 105        NaN        NaN        NaN        NaN        NaN        NaN
# 106        NaN        NaN        NaN        NaN        NaN        NaN
# 107        NaN        NaN        NaN        NaN        NaN        NaN
# 108        NaN        NaN        NaN        NaN        NaN        NaN
# 109        NaN        NaN        NaN        NaN        NaN        NaN
#
#     Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12 T 02.03.03.02
# 105        NaN         NaN         NaN         NaN           NaN
# 106        NaN         NaN         NaN         NaN           NaN
# 107        NaN         NaN         NaN         NaN           NaN
# 108        NaN         NaN         NaN         NaN           NaN
# 109        NaN         NaN         NaN         NaN           NaN

# %%
df.head()
# Out:
#   Klimadaten: Sonnenscheindauer                               Unnamed: 1  \
# 0                           NaN                                      NaN
# 1                           NaN                                      NaN
# 2                          Jahr  Jährliche Sonnenscheindauer, in Stunden
# 3                           NaN                                      NaN
# 4                           NaN                       Basel-Binningen 1)
#
#              Unnamed: 2 Unnamed: 3        Unnamed: 4     Unnamed: 5  \
# 0                   NaN        NaN               NaN            NaN
# 1                   NaN        NaN               NaN            NaN
# 2                   NaN        NaN               NaN            NaN
# 3                   NaN        NaN               NaN            NaN
# 4  Bern-Zollikofen 1,2)   Davos 1)  Genf-Cointrin 1)  Locarno-Monti
#
#   Unnamed: 6 Unnamed: 7    Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 0        NaN        NaN           NaN        NaN         NaN         NaN
# 1        NaN        NaN           NaN        NaN         NaN         NaN
# 2        NaN        NaN           NaN        NaN         NaN         NaN
# 3        NaN        NaN           NaN        NaN         NaN         NaN
# 4  Lugano 1)  Luzern 1)  Neuenburg 1)  Säntis 1)  Samedan 1)   Sitten 1)
#
#   Unnamed: 12       T 02.03.03.02
# 0         NaN                 NaN
# 1         NaN                 NaN
# 2         NaN                 NaN
# 3         NaN                 NaN
# 4  St. Gallen  Zürich-Fluntern 1)

# %%
import pandas as pd
Dataset = ("https://raw.githubusercontent.com/GRUPPE-BINA24/Datenspeicher/main/Durschn.Mietpreis_NachBaujahr.xlsx")
df=pd.read_excel(Dataset)
df.head()
# Out:
#   Durchschnittlicher Mietpreis1) in Franken nach Bauperiode und Kanton   \
# 0                                               2022
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                            Schweiz
#
#                        Unnamed: 1                           Unnamed: 2  \
# 0                             NaN                                  NaN
# 1                      Bauperiode                                  NaN
# 2                           Total                                  NaN
# 3  Durch-schnittlicher Mietpreis   Vertrauens-intervall : \n± (in Fr.)
# 4                            1412                                    3
#
#                        Unnamed: 3                           Unnamed: 4  \
# 0                             NaN                                  NaN
# 1                             NaN                                  NaN
# 2                        Vor 1919                                  NaN
# 3  Durch-schnittlicher Mietpreis   Vertrauens-intervall : \n± (in Fr.)
# 4                            1363                                   10
#
#                        Unnamed: 5                           Unnamed: 6  \
# 0                             NaN                                  NaN
# 1                             NaN                                  NaN
# 2                     1919 - 1945                                  NaN
# 3  Durch-schnittlicher Mietpreis   Vertrauens-intervall : \n± (in Fr.)
# 4                            1363                                   11
#
#                        Unnamed: 7                           Unnamed: 8  \
# 0                             NaN                                  NaN
# 1                             NaN                                  NaN
# 2                     1946 - 1960                                  NaN
# 3  Durch-schnittlicher Mietpreis   Vertrauens-intervall : \n± (in Fr.)
# 4                            1235                                    8
#
#                        Unnamed: 9  ...                     Unnamed: 11  \
# 0                             NaN  ...                             NaN
# 1                             NaN  ...                             NaN
# 2                     1961 - 1970  ...                     1971 - 1980
# 3  Durch-schnittlicher Mietpreis   ...  Durch-schnittlicher Mietpreis
# 4                            1216  ...                            1310
#
#                            Unnamed: 12                     Unnamed: 13  \
# 0                                  NaN                             NaN
# 1                                  NaN                             NaN
# 2                                  NaN                     1981 - 1990
# 3  Vertrauens-intervall : \n± (in Fr.)  Durch-schnittlicher Mietpreis
# 4                                    8                            1441
#
#                            Unnamed: 14                     Unnamed: 15  \
# 0                                  NaN                             NaN
# 1                                  NaN                             NaN
# 2                                  NaN                     1991 - 2000
# 3  Vertrauens-intervall : \n± (in Fr.)  Durch-schnittlicher Mietpreis
# 4                                   10                            1465
#
#                            Unnamed: 16                     Unnamed: 17  \
# 0                                  NaN                             NaN
# 1                                  NaN                             NaN
# 2                                  NaN                       2001-2010
# 3  Vertrauens-intervall : \n± (in Fr.)  Durch-schnittlicher Mietpreis
# 4                                   11                            1792
#
#                            Unnamed: 18                     Unnamed: 19  \
# 0                                  NaN                             NaN
# 1                                  NaN                             NaN
# 2                                  NaN                       2011-2022
# 3  Vertrauens-intervall : \n± (in Fr.)  Durch-schnittlicher Mietpreis
# 4                                   14                            1732
#
#                          T 09.03.03.02
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3  Vertrauens-intervall : \n± (in Fr.)
# 4                                    9
#
# [5 rows x 21 columns]

# %%
df.tail()
# Out:
#    Durchschnittlicher Mietpreis1) in Franken nach Bauperiode und Kanton   \
# 39  *: Entfällt, weil trivial oder Begriffe nicht ...
# 40                             Quellen: BFS – SE, GWS
# 41                                         © BFS 2024
# 42                                                NaN
# 43  Auskunft: Bundesamt für Statistik (BFS), Sekti...
#
#    Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 39        NaN        NaN        NaN        NaN        NaN        NaN
# 40        NaN        NaN        NaN        NaN        NaN        NaN
# 41        NaN        NaN        NaN        NaN        NaN        NaN
# 42        NaN        NaN        NaN        NaN        NaN        NaN
# 43        NaN        NaN        NaN        NaN        NaN        NaN
#
#    Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 11 Unnamed: 12 Unnamed: 13  \
# 39        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 40        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 41        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 42        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 43        NaN        NaN        NaN  ...         NaN         NaN         NaN
#
#    Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19  \
# 39         NaN         NaN         NaN         NaN         NaN         NaN
# 40         NaN         NaN         NaN         NaN         NaN         NaN
# 41         NaN         NaN         NaN         NaN         NaN         NaN
# 42         NaN         NaN         NaN         NaN         NaN         NaN
# 43         NaN         NaN         NaN         NaN         NaN         NaN
#
#    T 09.03.03.02
# 39           NaN
# 40           NaN
# 41           NaN
# 42           NaN
# 43           NaN
#
# [5 rows x 21 columns]

# %% [markdown]
# **Importieren von Daten zu leerstehenden Wohnungen:**

# %%
import pandas as pd
sourceFILE = 'https://raw.githubusercontent.com/SebastianMoos/BINAWALD/main/Leerstehende_Wohnungen_Kantone.csv'
df=pd.read_csv(sourceFILE)
df.head()
# Out:
#   Leerstehende Wohnungen (Anzahl) nach Kanton 1995 bis 2023  \
# 0                                                NaN
# 1                                     Gemeindenummer
# 2                                                 AG
# 3                                                 AI
# 4                                                 AR
#
#                Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0                     NaN         NaN         NaN         NaN         NaN
# 1                     Ort      1995.0      1996.0      1997.0      1998.0
# 2           Kanton Aargau      3237.0      3870.0      4950.0      5511.0
# 3  Kanton Appenzell I.Rh.        68.0       121.0       110.0       117.0
# 4  Kanton Appenzell A.Rh.       154.0       273.0       270.0       321.0
#
#    Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  Unnamed: 21  \
# 0         NaN         NaN         NaN         NaN  ...          NaN
# 1      1999.0      2000.0      2001.0      2002.0  ...       2014.0
# 2      5164.0      5063.0      4417.0      3378.0  ...       4957.0
# 3       107.0       135.0       119.0       104.0  ...         82.0
# 4       402.0       481.0       513.0       489.0  ...        502.0
#
#    Unnamed: 22  Unnamed: 23  Unnamed: 24  Unnamed: 25  Unnamed: 26  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1       2015.0       2016.0       2017.0       2018.0       2019.0
# 2       5975.0       6687.0       7323.0       8437.0       8377.0
# 3         63.0        282.0        186.0        150.0        163.0
# 4        549.0        562.0        577.0        628.0        669.0
#
#    Unnamed: 27  Unnamed: 28  Unnamed: 29  Unnamed: 30
# 0          NaN          NaN          NaN          NaN
# 1       2020.0       2021.0       2022.0       2023.0
# 2       8733.0       7009.0       5696.0       4778.0
# 3        174.0        215.0        139.0        134.0
# 4        482.0        605.0        549.0        359.0
#
# [5 rows x 31 columns]

# %%
df = pd.read_csv('https://raw.githubusercontent.com/SebastianMoos/BINAWALD/main/Leerstehende_Wohnungen_Kantone.csv', header=None)

# zweite Zeile als neue Spaltenüberschriften verwenden
new_columns = df.iloc[2]
df.columns = new_columns

# ersten beiden Zeilen entfernen
df = df.drop([0, 1, 2])

# Spaltenüberschriften in ganzzahligen Datentyp umwandeln
df.columns = df.columns.astype(int)


df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-36daefd7353b> in <cell line: 11>()
#       9
#      10 # Spaltenüberschriften in ganzzahligen Datentyp umwandeln
# ---> 11 df.columns = df.columns.astype(int)
#      12
#      13
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in astype(self, dtype, copy)
#    1025         else:
#    1026             # GH#13149 specifically use astype_array instead of astype
# -> 1027             new_values = astype_array(values, dtype=dtype, copy=copy)
#    1028
#    1029         # pass copy=False because any copying will be done in the astype above
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/dtypes/astype.py in astype_array(values, dtype, copy)
#     185
#     186     else:
# --> 187         values = _astype_nansafe(values, dtype, copy=copy)
#     188
#     189     # in pandas we don't store numpy str dtypes, so convert to object
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/dtypes/astype.py in _astype_nansafe(arr, dtype, copy, skipna)
#     136     if copy or is_object_dtype(arr.dtype) or is_object_dtype(dtype):
#     137         # Explicit copy, or required since NumPy can't view from / to object.
# --> 138         return arr.astype(dtype, copy=True)
#     139
#     140     return arr.astype(dtype, copy=copy)
#
# ValueError: invalid literal for int() with base 10: 'Gemeindenummer'

# %% [markdown]
# # Wenn man neue Daten von Github einbinden will immer den Teil:
# https://raw.githubusercontent.com/GRUPPE-BINA24/Datenspeicher/main/
# # Vorne hinstellen und dann den Dateinamen z.B.#
# *Durschn.Mietpreis_NachBaujahr.xlsx*... anhängen

# %% [markdown]
# #Referenzzinssatz

# %%
import pandas as pd
import numpy as np

# Daten von der URL laden
url = "https://raw.githubusercontent.com/GRUPPE-BINA24/Datenspeicher/main/Mietpreise_LIK_Zins_transponiert.xlsx"
daten = pd.read_excel(url)

# Spaltennamen anpassen, falls erforderlich
spalte1_name = 'Schweiz'
spalte2_name = 'Referenzzinssatz'

# Korrelationskoeffizient berechnen
korrelation = np.corrcoef(daten[spalte1_name], daten[spalte2_name])[0, 1]

print("Korrelationskoeffizient zwischen", spalte1_name, "und", spalte2_name, "ist:", korrelation)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Daten aus Excel-Datei laden
daten = pd.read_excel("https://raw.githubusercontent.com/GRUPPE-BINA24/Datenspeicher/main/Mietpreise_LIK_Zins_transponiert.xlsx")

# Spalten auswählen
x = daten['Schweiz']
y = daten['Referenzzinssatz']

# Streudiagramm erstellen
plt.scatter(x, y)
plt.title('Streudiagramm')
plt.xlabel('Mietpreise [CHF]')
plt.ylabel('Referenzzinssatz [Prozent]')
plt.xlim(15, 17.5)
plt.ylim(-1.5, 3)
plt.grid(True)
plt.show()

# %%
# Daten aus Excel-Datei laden
daten = pd.read_excel("https://raw.githubusercontent.com/GRUPPE-BINA24/Datenspeicher/main/Mietpreise_LIK_Zins_transponiert.xlsx")

# Spalten auswählen
x = daten['Schweiz']
y = daten['Referenzzinssatz']

# Streudiagramm erstellen
plt.scatter(x, y, label='Datenpunkte')
plt.plot(x, y, color='r', linestyle='-', linewidth=1, label='Verbundene Linie')  # Linie zwischen den Punkten
plt.title('Streudiagramm mit verbundener Linie')
plt.xlabel('Mietpreise [CHF]')
plt.ylabel('Referenzzinssatz [Prozent]')
plt.xlim(15, 17.5)
plt.ylim(-1.5, 3)
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# LIK

# %%
import pandas as pd
import numpy as np

# Daten von der URL laden
url = "https://raw.githubusercontent.com/GRUPPE-BINA24/Datenspeicher/main/Mietpreise_LIK_Zins_transponiert.xlsx"
daten = pd.read_excel(url)

# Spaltennamen anpassen, falls erforderlich
spalte1_name = 'Schweiz'
spalte2_name = 'LIK'

# Korrelationskoeffizient berechnen
korrelation = np.corrcoef(daten[spalte1_name], daten[spalte2_name])[0, 1]

print("Korrelationskoeffizient zwischen", spalte1_name, "und", spalte2_name, "ist:", korrelation)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Daten aus Excel-Datei laden
daten = pd.read_excel("https://raw.githubusercontent.com/GRUPPE-BINA24/Datenspeicher/main/Mietpreise_LIK_Zins_transponiert.xlsx")

# Spalten auswählen
x = daten['Schweiz']
y = daten['LIK']

# Streudiagramm erstellen
plt.scatter(x, y)
plt.title('Streudiagramm')
plt.xlabel('Mietpreise [CHF]')
plt.ylabel('LIK [Prozent]')
plt.xlim(15, 17.5)
plt.ylim(-1.5, 3)
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Daten aus Excel-Datei laden
daten = pd.read_excel("https://raw.githubusercontent.com/GRUPPE-BINA24/Datenspeicher/main/Mietpreise_LIK_Zins_transponiert.xlsx")

# Spalten auswählen
x = daten['Schweiz']
y = daten['LIK']

# Streudiagramm erstellen
plt.scatter(x, y, label='Datenpunkte')
plt.plot(x, y, color='r', linestyle='-', linewidth=1, label='Verbundene Linie')  # Linie zwischen den Punkten
plt.title('Streudiagramm mit verbundener Linie')
plt.xlabel('Mietpreise [CHF]')
plt.ylabel('LIK [Prozent]')
plt.xlim(15, 17.5)
plt.ylim(-1.5, 3)
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# #Kantonale Ebene

# %%
import pandas as pd
import numpy as np

# Daten von der URL laden
url = "https://raw.githubusercontent.com/GRUPPE-BINA24/Datenspeicher/main/Mietpreise_LIK_Zins_transponiert.xlsx"
daten = pd.read_excel(url)

# Spaltennamen anpassen, falls erforderlich
spalte1_name = 'Referenzzinssatz'
spalte2_name = 'Zürich'
spalte3_name = 'Bern'

# Korrelationskoeffizient berechnen
korrelation = np.corrcoef(daten[spalte1_name], daten[spalte2_name])[0, 1]


print("Korrelationskoeffizient zwischen", spalte1_name, "und", spalte2_name, "ist:", korrelation)

# %%
import pandas as pd
import numpy as np

# Daten aus Excel-Datei laden
daten = pd.read_excel("https://raw.githubusercontent.com/GRUPPE-BINA24/Datenspeicher/main/Mietpreise_LIK_Zins_transponiert.xlsx")

# Spalte, mit der verglichen werden soll
referenz_spalte = 'Referenzzinssatz'

# Liste der Spalten, mit denen verglichen werden soll
vergleich_spalten = ['Zürich', 'Bern', 'Luzern', 'Uri', 'Schwyz', 'Obwalden', 'Nidwalden', 'Glarus', 'Zug', 'Freiburg', 'Solothurn', 'Basel-Stadt', 'Basel-Landschaft', 'Schaffhausen', 'Appenzell A.Rh.', 'Appenzell I.Rh.', 'St.Gallen', 'Graubünden', 'Aargau', 'Thurgau', 'Tessin', 'Waadt', 'Wallis', 'Neuenburg', 'Genf', 'Jura' ]  # Fügen Sie hier weitere Spalten hinzu, falls erforderlich

# Korrelationskoeffizienten für jede Spalte berechnen
for spalte in vergleich_spalten:
    korrelation = np.corrcoef(daten[referenz_spalte], daten[spalte])[0, 1]
    print(f"Korrelationskoeffizient zwischen '{referenz_spalte}' und '{spalte}': {korrelation}")
# Out:
# Korrelationskoeffizient zwischen 'Referenzzinssatz' und 'Zürich': -0.7923169384222356
# Korrelationskoeffizient zwischen 'Referenzzinssatz' und 'Bern': -0.5338517086771244
# Korrelationskoeffizient zwischen 'Referenzzinssatz' und 'Luzern': -0.7642971663294115
# Korrelationskoeffizient zwischen 'Referenzzinssatz' und 'Uri': -0.3071534832741518
# Korrelationskoeffizient zwischen 'Referenzzinssatz' und 'Schwyz': -0.17135710334660975
# Korrelationskoeffizient zwischen 'Referenzzinssatz' und 'Obwalden': -0.052065610860648016
# Korrelationskoeffizient zwischen 'Referenzzinssatz' und 'Nidwalden': -0.28188937975929734
# Korrelationskoeffizient zwischen 'Referenzzinssatz' und 'Glarus': -0.7290050043469348
# Korrelationskoeffizient zwischen 'Referenzzinssatz' und 'Zug': -0.3108324081344303
# Korrelationskoeffizient zwischen 'Referenzzinssatz' und 'Freiburg': -0.4361874141413972
# Korrelationskoeffizient zwischen 'Referenzzinssatz' und 'Solothurn': -0.480621691769859
# Korrelationskoeffizient zwischen 'Referenzzinssatz' und 'Basel-Stadt': -0.8826735624932512
# Korrelationskoeffizient zwischen 'Referenzzinssatz' und 'Basel-Landschaft': -0.597621016380459
# Korrelationskoeffizient zwischen 'Referenzzinssatz' und 'Schaffhausen': -0.5967130793205242
# Korrelationskoeffizient zwischen 'Referenzzinssatz' und 'Appenzell A.Rh.': -0.6905829678974545
# Korrelationskoeffizient zwischen 'Referenzzinssatz' und 'Appenzell I.Rh.': -0.5902804471615276
# Korrelationskoeffizient zwischen 'Referenzzinssatz' und 'St.Gallen': -0.5441285170639052
# Korrelationskoeffizient zwischen 'Referenzzinssatz' und 'Graubünden': 0.23268592555369438
# Korrelationskoeffizient zwischen 'Referenzzinssatz' und 'Aargau': -0.6479070718913947
# Korrelationskoeffizient zwischen 'Referenzzinssatz' und 'Thurgau': -0.7529777884169491
# Korrelationskoeffizient zwischen 'Referenzzinssatz' und 'Tessin': -0.6893756311136561
# Korrelationskoeffizient zwischen 'Referenzzinssatz' und 'Waadt': -0.8247374320234951
# Korrelationskoeffizient zwischen 'Referenzzinssatz' und 'Wallis': -0.6046086526753385
# Korrelationskoeffizient zwischen 'Referenzzinssatz' und 'Neuenburg': -0.4529991294232822
# Korrelationskoeffizient zwischen 'Referenzzinssatz' und 'Genf': -0.774123455625363
# Korrelationskoeffizient zwischen 'Referenzzinssatz' und 'Jura': -0.3226663982951855

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Daten aus Excel-Datei laden
daten = pd.read_excel("https://raw.githubusercontent.com/GRUPPE-BINA24/Datenspeicher/main/Mietpreise_LIK_Zins_transponiert.xlsx")

# Spalten auswählen
x = daten['Zürich']
y = daten['Referenzzinssatz']

# Streudiagramm erstellen
plt.scatter(x, y, label='Datenpunkte')
plt.plot(x, y, color='r', linestyle='-', linewidth=1, label='Verbundene Linie')  # Linie zwischen den Punkten
plt.title('Streudiagramm mit verbundener Linie')
plt.xlabel('Mietpreise [CHF]')
plt.ylabel('Referenzzinsatz [Prozent]')
plt.ylim(-1.5, 3)
plt.grid(True)
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Daten aus Excel-Datei laden
daten = pd.read_excel("https://raw.githubusercontent.com/GRUPPE-BINA24/Datenspeicher/main/Mietpreise_LIK_Zins_transponiert.xlsx")

# Spalten auswählen
x = daten['Bern']
y = daten['Referenzzinssatz']

# Streudiagramm erstellen
plt.scatter(x, y, label='Datenpunkte')
plt.plot(x, y, color='r', linestyle='-', linewidth=1, label='Verbundene Linie')  # Linie zwischen den Punkten
plt.title('Streudiagramm mit verbundener Linie')
plt.xlabel('Mietpreise [CHF]')
plt.ylabel('Referenzzinsatz [Prozent]')
plt.ylim(-1.5, 3)
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# Versucht Dropdown

# %%
import plotly.graph_objects as go
import pandas as pd


# Liste der verfügbaren Kantone
kantone = merged_df['Kanton'].unique()

# Dropdown-Menü erstellen
dropdown = go.layout.Updatemenu(
    buttons=list([
        dict(label=kanton,
             method="update",
             args=[{"visible": merged_df['Kanton'] == kanton},
                   {"title": f"Scatterplot für {kanton}"}])
        for kanton in kantone
    ]),
)

# Layout für den Plot definieren
layout = go.Layout(
    title='Scatterplot Mietpreis, Leerwohnungsziffer 2010 bis 2022',
    updatemenus=[dropdown],
)

# Scatterplot erstellen
fig = go.Figure(layout=layout)

for kanton in kantone:
    df_kanton = merged_df[merged_df['Kanton'] == kanton]
    fig.add_trace(go.Scatter(x=df_kanton['Mietpreis pro m2'],
                             y=df_kanton['Leerwohnungsziffer'],
                             mode='markers',
                             name=kanton))

fig.show()

# %%
['Zürich', 'Bern', 'Luzern', 'Uri', 'Schwyz', 'Obwalden', 'Nidwalden', 'Glarus', 'Zug', 'Freiburg', 'Solothurn', 'Basel-Stadt', 'Basel-Landschaft', 'Schaffhausen', 'Appenzell A.Rh.', 'Appenzell I.Rh.', 'St.Gallen', 'Graubünden', 'Aargau', 'Thurgau', 'Tessin', 'Waadt', 'Wallis', 'Neuenburg', 'Genf', 'Jura' ]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Daten aus Excel-Datei laden
daten = pd.read_excel("https://raw.githubusercontent.com/GRUPPE-BINA24/Datenspeicher/main/Mietpreise_LIK_Zins_transponiert.xlsx")

# Spalten auswählen
x = daten['Zürich', 'Bern']
y = daten['Referenzzinssatz']

# Streudiagramm erstellen
plt.scatter(x, y, label='Datenpunkte')
plt.plot(x, y, color='r', linestyle='-', linewidth=1, label='Verbundene Linie')  # Linie zwischen den Punkten
plt.title('Streudiagramm mit verbundener Linie')
plt.xlabel('Mietpreise [CHF]')
plt.ylabel('Referenzzinsatz [Prozent]')
plt.ylim(-1.5, 3)
plt.grid(True)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Zürich', 'Bern')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-e964c18e6186> in <cell line: 8>()
#       6
#       7 # Spalten auswählen
# ----> 8 x = daten['Zürich', 'Bern']
#       9 y = daten['Referenzzinssatz']
#      10
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3759             if self.columns.nlevels > 1:
#    3760                 return self._getitem_multilevel(key)
# -> 3761             indexer = self.columns.get_loc(key)
#    3762             if is_integer(indexer):
#    3763                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
# -> 3655             raise KeyError(key) from err
#    3656         except TypeError:
#    3657             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: ('Zürich', 'Bern')
