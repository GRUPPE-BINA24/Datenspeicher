# %% [markdown]
# <a href="https://colab.research.google.com/github/GRUPPE-BINA24/Datenspeicher/blob/main/Kopie_von_Semesterarbeit_BINA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Leerstehende Wohnungen (nach Kanton) Absolute Werte**

# %% [markdown]
# Daten importieren und bereinigen

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline


df = pd.read_csv('https://raw.githubusercontent.com/GRUPPE-BINA24/Datenspeicher/main/Leerstehende_Wohnungen_Kantone.csv', header=None)

dataLeerstehend=df

# zweite Zeile als neue Spaltenüberschriften verwenden
new_columns = dataLeerstehend.iloc[2]
dataLeerstehend.columns = new_columns

# ersten beiden Zeilen entfernen
dataLeerstehend = dataLeerstehend.drop([0, 1, 2])

dataLeerstehend.columns = dataLeerstehend.columns[:2].tolist() + dataLeerstehend.columns[2:].astype(int).tolist()



dataLeerstehend.head()
# Out:
#   Gemeindenummer                      Ort    1995    1996    1997    1998  \
# 3             AG            Kanton Aargau  3237.0  3870.0  4950.0  5511.0
# 4             AI   Kanton Appenzell I.Rh.    68.0   121.0   110.0   117.0
# 5             AR   Kanton Appenzell A.Rh.   154.0   273.0   270.0   321.0
# 6             BE              Kanton Bern  4250.0  5360.0  6419.0  7012.0
# 7             BL  Kanton Basel-Landschaft   451.0   502.0   632.0   644.0
#
#      1999    2000    2001    2002  ...    2014    2015    2016     2017  \
# 3  5164.0  5063.0  4417.0  3378.0  ...  4957.0  5975.0  6687.0   7323.0
# 4   107.0   135.0   119.0   104.0  ...    82.0    63.0   282.0    186.0
# 5   402.0   481.0   513.0   489.0  ...   502.0   549.0   562.0    577.0
# 6  6800.0  6702.0  6388.0  5335.0  ...  7761.0  8012.0  9309.0  10262.0
# 7   668.0   687.0   679.0   498.0  ...   427.0   528.0   645.0    809.0
#
#       2018     2019     2020    2021    2022    2023
# ...

# %%
# Spalte Gemeindenummer entfernen
dataLeerstehend = dataLeerstehend.drop(['Gemeindenummer'], axis = 1)
dataLeerstehend.head()
# Out:
#                        Ort    1995    1996    1997    1998    1999    2000  \
# 3            Kanton Aargau  3237.0  3870.0  4950.0  5511.0  5164.0  5063.0
# 4   Kanton Appenzell I.Rh.    68.0   121.0   110.0   117.0   107.0   135.0
# 5   Kanton Appenzell A.Rh.   154.0   273.0   270.0   321.0   402.0   481.0
# 6              Kanton Bern  4250.0  5360.0  6419.0  7012.0  6800.0  6702.0
# 7  Kanton Basel-Landschaft   451.0   502.0   632.0   644.0   668.0   687.0
#
#      2001    2002    2003  ...    2014    2015    2016     2017     2018  \
# 3  4417.0  3378.0  2844.0  ...  4957.0  5975.0  6687.0   7323.0   8437.0
# 4   119.0   104.0    86.0  ...    82.0    63.0   282.0    186.0    150.0
# 5   513.0   489.0   513.0  ...   502.0   549.0   562.0    577.0    628.0
# 6  6388.0  5335.0  5116.0  ...  7761.0  8012.0  9309.0  10262.0  10317.0
# 7   679.0   498.0   506.0  ...   427.0   528.0   645.0    809.0   1060.0
#
#       2019     2020    2021    2022    2023
# ...

# %%
#Anzahl der Werte anzeigen
dataLeerstehend.count()
# Out:
# Ort     26
# 1995    26
# 1996    26
# 1997    26
# 1998    26
# 1999    26
# 2000    26
# 2001    26
# 2002    26
# 2003    26
# 2004    26
# 2005    26
# 2006    26
# 2007    26
# 2008    26
# 2009    26
# 2010    26
# 2011    26
# 2012    26
# 2013    26
# 2014    26
# 2015    26
# 2016    26
# 2017    26
# 2018    26
# 2019    26
# 2020    26
# 2021    26
# 2022    26
# 2023    26
# dtype: int64

# %% [markdown]
# Mittelwert, Median und Modus berechne

# %%
#Mittelwert berechnen
dataLeerstehend.mean()
# Out:
# <ipython-input-5-b648754134e0>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dataLeerstehend.mean()
# 1995    1783.346154
# 1996    2095.384615
# 1997    2405.500000
# 1998    2469.153846
# 1999    2233.615385
# 2000    2023.384615
# 2001    1738.807692
# 2002    1447.000000
# 2003    1270.730769
# 2004    1291.538462
# 2005    1415.461538
# 2006    1528.923077
# 2007    1555.923077
# 2008    1427.615385
# 2009    1336.961538
# 2010    1412.038462
# 2011    1477.576923
# 2012    1510.923077
# 2013    1554.730769
# 2014    1744.423077
# 2015    1941.384615
# 2016    2173.769231
# 2017    2472.076923
# 2018    2780.538462
# 2019    2899.346154
# 2020    3032.000000
# 2021    2744.807692
# 2022    2365.230769
# 2023    2106.346154
# dtype: float64

# %%
#Median berechnen
dataLeerstehend.median()
# Out:
# <ipython-input-6-6ec338196543>:2: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dataLeerstehend.median()
# 1995    1221.5
# 1996    1465.5
# 1997    1761.0
# 1998    1694.5
# 1999    1653.5
# 2000    1479.0
# 2001    1295.5
# 2002    1133.0
# 2003     993.0
# 2004    1023.0
# 2005    1079.5
# 2006    1107.5
# 2007    1172.0
# 2008    1102.5
# 2009     949.5
# 2010     950.0
# 2011     832.0
# 2012     875.5
# 2013     769.5
# 2014     907.5
# 2015    1051.0
# 2016    1052.5
# 2017    1305.5
# 2018    1574.5
# 2019    1886.5
# 2020    1941.5
# 2021    1470.0
# 2022    1340.5
# 2023    1325.5
# dtype: float64

# %%
#Modus berechnen
dataLeerstehend.mode()
# Out:
#                         Ort    1995    1996    1997    1998    1999    2000  \
# 0             Kanton Aargau    68.0   121.0   110.0   117.0   107.0   114.0
# 1    Kanton Appenzell A.Rh.   105.0   128.0   179.0   176.0   169.0   129.0
# 2    Kanton Appenzell I.Rh.   118.0   171.0   214.0   209.0   190.0   135.0
# 3   Kanton Basel-Landschaft   129.0   190.0   270.0   278.0   235.0   157.0
# 4        Kanton Basel-Stadt   154.0   273.0   296.0   321.0   275.0   286.0
# 5               Kanton Bern   249.0   355.0   356.0   366.0   402.0   481.0
# 6           Kanton Freiburg   273.0   440.0   508.0   537.0   568.0   653.0
# 7               Kanton Genf   451.0   502.0   632.0   637.0   668.0   668.0
# 8             Kanton Glarus   536.0   641.0   703.0   644.0   686.0   687.0
# 9         Kanton Graubünden   538.0   686.0   887.0   882.0   907.0   779.0
# 10              Kanton Jura   550.0   804.0  1168.0  1044.0   918.0  1109.0
# ...

# %% [markdown]
# Boxplot für die Anzahl Leerstehenden Wohnungen berechnen (nach Jahr)

# %%
dataLeerstehend.boxplot(column=[1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023], figsize=(20, 6))


plt.xlabel('Jahr')
plt.ylabel('Anzahl Leerstehende Wohnungen')
plt.title('Boxplot Anzahl Leerstehende Wohnungen (1995 bis 2023)')
# Out:
# Text(0.5, 1.0, 'Boxplot Anzahl Leerstehende Wohnungen (1995 bis 2023)')

# %% [markdown]
# Boxplot für die Anzahl leerstehender Wohnungen (nach Kanton)

# %%
#Transponieren der Tabelle (Kantone zu Spalten, da Boxplot für Spalten ausgelegt) und speicher eines neuen CSVs
dataLeerstehend_Kanton = dataLeerstehend.T

dataLeerstehend_Kanton.to_csv('Kanton_Daten_Spalten.csv', index=False)
# Out:
#                  3                       4                       5   \
# Ort   Kanton Aargau  Kanton Appenzell I.Rh.  Kanton Appenzell A.Rh.
# 1995         3237.0                    68.0                   154.0
# 1996         3870.0                   121.0                   273.0
# 1997         4950.0                   110.0                   270.0
# 1998         5511.0                   117.0                   321.0
#
#                6                        7                   8   \
# Ort   Kanton Bern  Kanton Basel-Landschaft  Kanton Basel-Stadt
# 1995       4250.0                    451.0               550.0
# 1996       5360.0                    502.0               804.0
# 1997       6419.0                    632.0              1249.0
# 1998       7012.0                    644.0              1578.0
#
#                    9            10             11                 12  ...  \
# Ort   Kanton Freiburg  Kanton Genf  Kanton Glarus  Kanton Graubünden  ...
# ...

# %%
#neues df erstellen (Import CSV)
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline


df = pd.read_csv('https://raw.githubusercontent.com/GRUPPE-BINA24/Datenspeicher/main/Daten_Kanton_Spalten.csv', header=0)


Data_Kanton=df


Data_Kanton.head()
# Out:
#    Jahr  Kanton Aargau  Kanton Appenzell I.Rh.  Kanton Appenzell A.Rh.  \
# 0  1995           3237                      68                     154
# 1  1996           3870                     121                     273
# 2  1997           4950                     110                     270
# 3  1998           5511                     117                     321
# 4  1999           5164                     107                     402
#
#    Kanton Bern  Kanton Basel-Landschaft  Kanton Basel-Stadt  Kanton Freiburg  \
# 0         4250                      451                 550             1548
# 1         5360                      502                 804             1771
# 2         6419                      632                1249             2248
# 3         7012                      644                1578             2197
# 4         6800                      668                1602             2218
#
# ...

# %%
#Daten der Grösse nach sortieren:

# neue Zeile Mittelwert einfügen
Data_Kanton.loc['Mittelwert'] = Data_Kanton.mean()

# Spalten nach dem Mittelwert sortieren und neues df generieren
Kanton_Sorted = Data_Kanton.sort_values(by='Mittelwert', axis=1)

Kanton_Sorted.head()
# Out:
#    Kanton Appenzell I.Rh.  Kanton Obwalden  Kanton Uri  Kanton Zug  \
# 0                    68.0            129.0       105.0       249.0
# 1                   121.0            171.0       190.0       440.0
# 2                   110.0            214.0       296.0       356.0
# 3                   117.0            209.0       278.0       366.0
# 4                   107.0            235.0       275.0       190.0
#
#    Kanton Nidwalden  Kanton Glarus  Kanton Appenzell A.Rh.  \
# 0             118.0          273.0                   154.0
# 1             128.0          355.0                   273.0
# 2             179.0          508.0                   270.0
# 3             176.0          537.0                   321.0
# 4             169.0          568.0                   402.0
#
#    Kanton Schaffhausen  Kanton Schwyz  Kanton Jura  ...    Jahr  \
# 0                536.0          849.0        538.0  ...  1995.0
# 1                686.0         1149.0        641.0  ...  1996.0
# ...

# %%
#  "Mittelwert"-Zeile und Jahr-Spalte enfernen, damit sie nicht im Boxplot erscheinen


Kanton_Final = Kanton_Sorted.drop('Jahr', axis=1).drop('Mittelwert')

Kanton_Final.head()
# Out:
#    Kanton Appenzell I.Rh.  Kanton Obwalden  Kanton Uri  Kanton Zug  \
# 0                    68.0            129.0       105.0       249.0
# 1                   121.0            171.0       190.0       440.0
# 2                   110.0            214.0       296.0       356.0
# 3                   117.0            209.0       278.0       366.0
# 4                   107.0            235.0       275.0       190.0
#
#    Kanton Nidwalden  Kanton Glarus  Kanton Appenzell A.Rh.  \
# 0             118.0          273.0                   154.0
# 1             128.0          355.0                   273.0
# 2             179.0          508.0                   270.0
# 3             176.0          537.0                   321.0
# 4             169.0          568.0                   402.0
#
#    Kanton Schaffhausen  Kanton Schwyz  Kanton Jura  ...  Kanton Luzern  \
# 0                536.0          849.0        538.0  ...         1261.0
# ...

# %%
#Boxplot erstellen und vertikale Beschriftung einfügen
Kanton_Final.boxplot(figsize=(20, 6))

plt.xticks(rotation='vertical')

plt.ylabel('Anzahl Leerstehende Wohnungen')
plt.title('Boxplot Anzahl Leerstehende Wohnungen (Kantone)')
# Out:
# Text(0.5, 1.0, 'Boxplot Anzahl Leerstehende Wohnungen (Kantone)')

# %%
#Boxplot mit Seaborn

import seaborn as sns
import matplotlib.pyplot as plt

# Annahme: Data_Kanton ist dein DataFrame

# Erstelle einen Boxplot mit Seaborn
plt.figure(figsize=(20, 6))
sns.boxplot(data=Kanton_Final)
plt.xticks(rotation='vertical')
plt.show()

# %%
#Boxplot als interaktive Grafik (mit Plotly Bibliothek)

# !pip install plotly

import plotly.express as px
import pandas as pd

# Annahme: Data_Kanton ist dein DataFrame

# Erstelle den Boxplot mit Plotly
fig = px.box(Kanton_Final)

# Zeige den Boxplot an
fig.show()
# Out:
# ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Leerhwohnungsziffern (Kanton und Jahr)
#
# ---
#
#
#
#
#
# *  Leerwohnungsziffer beschreibt den prozentualen Anteil Leerstehender Wohnungen

# %% [markdown]
# **Leerwohnungziffer nach Jahre**

# %%
#Datenimport

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline


df = pd.read_csv('https://raw.githubusercontent.com/GRUPPE-BINA24/Datenspeicher/main/Leerwohnungsziffer_Kantone.csv', header=0)

Leerwohnungsziffer=df

Leerwohnungsziffer.head()
# Out:
#                     Kanton 1995 1996  1997  1998  1999  2000  2001  2002  \
# 0            Kanton Aargau  ...  ...  2.17  2.38  2.20  2.13  1.83  1.39
# 1   Kanton Appenzell I.Rh.  ...  ...  1.81  1.91  1.74  2.17  1.90  1.65
# 2   Kanton Appenzell A.Rh.  ...  ...  1.10  1.30  1.62  1.92  2.04  1.94
# 3              Kanton Bern  ...  ...  1.40  1.51  1.46  1.42  1.35  1.12
# 4  Kanton Basel-Landschaft  ...  ...  0.57  0.57  0.58  0.59  0.57  0.42
#
#    2003  ...  2014  2015  2016  2017  2018  2019  2020  2021  2022  2023
# 0  1.16  ...  1.67  1.98  2.18  2.34  2.65  2.59  2.65  2.10  1.69  1.40
# 1  1.39  ...  1.12  0.83  3.63  2.36  1.89  2.02  2.15  2.59  1.67  1.59
# 2  2.03  ...  1.81  1.96  1.99  2.02  2.18  2.30  1.64  2.05  1.84  1.20
# 3  1.08  ...  1.44  1.47  1.69  1.84  1.83  1.87  1.86  1.61  1.48  1.33
# 4  0.42  ...  0.32  0.39  0.47  0.58  0.76  1.06  1.14  0.97  0.93  0.92
#
# [5 rows x 30 columns]

# %%
#Boxplot erstellen mit Mathplotlib

Leerwohnungsziffer.boxplot(figsize=(20, 6))


plt.xlabel('Jahr')
plt.ylabel('Leerwohnungziffer (Anteil Gesamte Wohnungen)')
plt.title('Boxplot Leerhwohnungsziffer (1995 bis 2023)')
# Out:
# Text(0.5, 1.0, 'Boxplot Leerhwohnungsziffer (1995 bis 2023)')

# %% [markdown]
# **Leerhwohnungsziffer nach Kantone**

# %%
#Transponieren der Tabelle (Kantone zu Spalten, da Boxplot für Spalten ausgelegt) und speicher eines neuen CSVs
Leerwohnungsziffer_Kanton = Leerwohnungsziffer.T

Leerwohnungsziffer_Kanton.to_csv('Leerwohnugsziffer_Kantone.csv', index=False)

# %%
# Neues df aus CSV Datei erstellen

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline


df = pd.read_csv('https://raw.githubusercontent.com/GRUPPE-BINA24/Datenspeicher/main/Leerwohnugsziffer_Kantone_Spalten.csv', header=0)


Leerwohnungsziffer_Kanton=df


Leerwohnungsziffer_Kanton.head()
# Out:
#    Kanton Aargau  Kanton Appenzell I.Rh.  Kanton Appenzell A.Rh.  Kanton Bern  \
# 0           2.17                    1.81                    1.10         1.40
# 1           2.38                    1.91                    1.30         1.51
# 2           2.20                    1.74                    1.62         1.46
# 3           2.13                    2.17                    1.92         1.42
# 4           1.83                    1.90                    2.04         1.35
#
#    Kanton Basel-Landschaft  Kanton Basel-Stadt  Kanton Freiburg  Kanton Genf  \
# 0                     0.57                1.20             2.30         1.58
# 1                     0.57                1.52             2.21         1.61
# 2                     0.58                1.54             2.20         1.36
# 3                     0.59                1.31             1.82         0.86
# 4                     0.57                1.41             1.78         0.39
#
# ...

# %%
#Daten der Grösse nach sortieren:

# neue Zeile Mittelwert einfügen
Leerwohnungsziffer_Kanton.loc['Mittelwert'] = Leerwohnungsziffer_Kanton.mean()

# Spalten nach dem Mittelwert sortieren und neues df generieren
Leerwohnungsziffer_Kanton = Leerwohnungsziffer_Kanton.sort_values(by='Mittelwert', axis=1)

Leerwohnungsziffer_Kanton.head()
# Out:
#    Kanton Zug  Kanton Genf  Kanton Basel-Landschaft  Kanton ZÃ¼rich  \
# 0        0.92         1.58                     0.57            1.17
# 1        0.92         1.61                     0.57            1.15
# 2        0.47         1.36                     0.58            0.97
# 3        0.31         0.86                     0.59            0.71
# 4        0.31         0.39                     0.57            0.47
#
#    Kanton Obwalden  Kanton Waadt  Kanton Basel-Stadt  Kanton Schwyz  \
# 0             1.37          2.68                1.20           2.23
# 1             1.31          2.45                1.52           1.96
# 2             1.45          1.81                1.54           1.69
# 3             0.96          1.38                1.31           1.41
# 4             0.79          1.00                1.41           1.03
#
#    Kanton Luzern  Kanton GraubÃ¼nden  ...  Kanton Appenzell I.Rh.  \
# 0           1.65                1.40  ...                    1.81
# ...

# %%
#  "Mittelwert"-Zeile entfernen, damit sie nicht im Boxplot erscheint


Leerwohnungsziffer_Kanton = Leerwohnungsziffer_Kanton.drop('Mittelwert')

Leerwohnungsziffer_Kanton.head()
# Out:
#    Kanton Zug  Kanton Genf  Kanton Basel-Landschaft  Kanton ZÃ¼rich  \
# 0        0.92         1.58                     0.57            1.17
# 1        0.92         1.61                     0.57            1.15
# 2        0.47         1.36                     0.58            0.97
# 3        0.31         0.86                     0.59            0.71
# 4        0.31         0.39                     0.57            0.47
#
#    Kanton Obwalden  Kanton Waadt  Kanton Basel-Stadt  Kanton Schwyz  \
# 0             1.37          2.68                1.20           2.23
# 1             1.31          2.45                1.52           1.96
# 2             1.45          1.81                1.54           1.69
# 3             0.96          1.38                1.31           1.41
# 4             0.79          1.00                1.41           1.03
#
#    Kanton Luzern  Kanton GraubÃ¼nden  ...  Kanton Appenzell I.Rh.  \
# 0           1.65                1.40  ...                    1.81
# ...

# %%
#Boxplot erstellen und vertikale Beschriftung einfügen
Leerwohnungsziffer_Kanton.boxplot(figsize=(20, 6))

plt.xticks(rotation='vertical')

plt.ylabel('Leerwohnungsziffer')
plt.title('Boxplot Leerwohnungsziffer nach Kanton (1997 bis 2023)')
# Out:
# Text(0.5, 1.0, 'Boxplot Leerwohnungsziffer nach Kanton (1997 bis 2023)')

# %%
#Boxplot als interaktive Grafik (mit Plotly Bibliothek)

# !pip install plotly

import plotly.express as px
import pandas as pd


# Erstelle den Boxplot mit Plotly
fig = px.box(Leerwohnungsziffer_Kanton)

# Zeige den Boxplot an
fig.show()
# Out:
# ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Korrelation Leerhwohnungsziffer und Bevölkerung

# %% [markdown]
# Bevölkerungsdaten bearbeiten

# %%
#CSV File Bevölkerung ZH importieren

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

Bevölkerung_ZH = pd.read_csv('https://raw.githubusercontent.com/GRUPPE-BINA24/Datenspeicher/main/Bev%C3%B6lkerung_ZH.csv')


Bevölkerung_ZH.head()
# Out:
#    BFS_NR  GEBIET_NAME                THEMA_NAME  \
# 0       1  Aeugst a.A.  Bevölkerung und Soziales
# 1       1  Aeugst a.A.  Bevölkerung und Soziales
# 2       1  Aeugst a.A.  Bevölkerung und Soziales
# 3       1  Aeugst a.A.  Bevölkerung und Soziales
# 4       1  Aeugst a.A.  Bevölkerung und Soziales
#
#                             SET_NAME          SUBSET_NAME  INDIKATOR_ID  \
# 0  Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           133
# 1  Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           133
# 2  Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           133
# 3  Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           133
# 4  Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           133
#
#         INDIKATOR_NAME  INDIKATOR_JAHR  INDIKATOR_VALUE EINHEIT_KURZ  \
# 0  Bevölkerung [Pers.]            1962              710        Pers.
# 1  Bevölkerung [Pers.]            1963              720        Pers.
# ...

# %%
# Pivot funktion nutzen, um Total Jahreszahlen (Kanton) zu erhalten

pivot_table_Bev = Bevölkerung_ZH.pivot_table(index=['INDIKATOR_JAHR'], values=['INDIKATOR_VALUE'], aggfunc='sum')

pivot_table_Bev.head()
# Out:
#                 INDIKATOR_VALUE
# INDIKATOR_JAHR
# 1962                    4057018
# 1963                    4125883
# 1964                    4176172
# 1965                    4208047
# 1966                    4257103

# %% [markdown]
# Leerwohnungdaten *bearbeiten*

# %%
#CSV File Bevölkerung ZH importieren

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

Leerhwohnungen_ZH = pd.read_csv('https://raw.githubusercontent.com/GRUPPE-BINA24/Datenspeicher/main/Leerhwohnungen_ZH.csv')

Leerhwohnungen_ZH.head()
# Out:
#    stichjahr  bfs wohnungstyp zimmerzahl  anz_leerwohnungen
# 0       1994    1  Alle Typen      total                 10
# 1       1994    1  Alle Typen          1                  2
# 2       1994    1  Alle Typen          2                  2
# 3       1994    1  Alle Typen          3                  1
# 4       1994    1  Alle Typen          4                  3

# %%
# Pivot funktion nutzen, um Total Jahreszahlen (Kanton) zu erhalten

pivot_table_LW = Leerhwohnungen_ZH.pivot_table(index=['stichjahr'], values=['anz_leerwohnungen'], aggfunc='sum')

pivot_table_LW.head()
# Out:
#            anz_leerwohnungen
# stichjahr
# 1994                   25656
# 1995                   31384
# 1996                   43976
# 1997                   53056
# 1998                   53048

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


# Auswahl der Spalten, die verglichen werden sollen
column1 = 'INDIKATOR_VALUE'
column2 = 'anz_leerwohnungen'  # Name der Spalte in der zweiten Datei

# Berechnen der Korrelation zwischen den ausgewählten Spalten
correlation = pivot_table_Bev[column1].corr(pivot_table_LW[column2])

print(f"Korrelation zwischen {column1} und {column2}: {correlation}")

# Visualisierung der Korrelation (Streudiagramm)
plt.figure(figsize=(8, 6))
sns.scatterplot(data=pivot_table_Bev, x=column1, y=pivot_table_LW[column2])
plt.title(f"Korrelation zwischen {column1} und {column2}")
plt.xlabel(column1)
plt.ylabel(column2)
plt.grid(True)
plt.show()
# Out:
# Korrelation zwischen INDIKATOR_VALUE und anz_leerwohnungen: 0.37961981437937853

# %% [markdown]
# # Vergleich Mietpreise und Leerwohnungsziffern (2010 bis 2022)

# %% [markdown]
# ## Visualisierung Mietpreise (einzeln)

# %% [markdown]
# Data Engineering

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline


Mietpreise_raw = pd.read_csv('https://raw.githubusercontent.com/GRUPPE-BINA24/Datenspeicher/main/Durschn.Mietpreis_NachBaujahr_Zusammengef%C3%BChrt.csv', header=1)

Mietpreise_raw.head()
# Out:
#    Jahr  Kanton  Durch-schnittlicher Mietpreis   \
# 0  2022  Zürich                            1654
# 1  2022    Bern                            1259
# 2  2022  Luzern                            1411
# 3  2022     Uri                            1222
# 4  2022  Schwyz                            1616
#
#    Vertrauens-intervall : \n± (in Fr.)
# 0                                    8
# 1                                    8
# 2                                    9
# 3                                   43
# 4                                   29

# %%
#Ersetzen der Spaltenüberschriften
Mietpreise_raw.columns = ['Jahr', 'Kanton', 'Durschnittlicher_Mietpreis_CHF', 'Vertrauensintervall']

Mietpreise_raw.head()
# Out:
#    Jahr  Kanton  Durschnittlicher_Mietpreis_CHF  Vertrauensintervall
# 0  2022  Zürich                            1654                    8
# 1  2022    Bern                            1259                    8
# 2  2022  Luzern                            1411                    9
# 3  2022     Uri                            1222                   43
# 4  2022  Schwyz                            1616                   29

# %%
print(Mietpreise_raw)
# Out:
#      Jahr     Kanton  Durschnittlicher_Mietpreis_CHF  Vertrauensintervall
# 0    2022     Zürich                            1654                    8
# 1    2022       Bern                            1259                    8
# 2    2022     Luzern                            1411                    9
# 3    2022        Uri                            1222                   43
# 4    2022     Schwyz                            1616                   29
# ..    ...        ...                             ...                  ...
# 333  2010      Waadt                            1237                   11
# 334  2010     Wallis                            1040                   24
# 335  2010  Neuenburg                             967                   15
# 336  2010       Genf                            1334                   15
# 337  2010       Jura                             902                   26
#
# [338 rows x 4 columns]

# %%
#Prüfen ob richtiger Datentyp (INT)
print(Mietpreise_raw.dtypes)
# Out:
# Jahr                               int64
# Kanton                            object
# Durschnittlicher_Mietpreis_CHF     int64
# Vertrauensintervall                int64
# dtype: object

# %% [markdown]
# Plot (Liniendiagramm)

# %%
#Plot der Mietpreise je Kanton und Jahr
plt.figure(figsize=(20, 10))
for kanton, group_data in Mietpreise_raw.groupby('Kanton'):
    plt.plot(group_data['Jahr'], group_data['Durschnittlicher_Mietpreis_CHF'], marker='o', label=kanton)

plt.title('Mietpreis nach Jahr und Kanton')
plt.xlabel('Jahr')
plt.ylabel('Mietpreis')
plt.grid(True)
plt.legend()  # Legende hinzufügen, um die Linien den Kantonen zuzuordnen
plt.tight_layout()
plt.show()

# %%
df_merged = pd.merge(Mietpreise_raw, df_leerwohnungsziffer, on=['Jahr', 'Kanton'])

# %% [markdown]
# # Scatterplot (Korrelation Leerhwounungsziffer, durschnittlicher Mietpreis je Kanton 2010 bis 2022)

# %% [markdown]
# Import der Mietzins-Daten

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline


Mietpreise_raw = pd.read_csv('https://raw.githubusercontent.com/GRUPPE-BINA24/Datenspeicher/main/Durschn.Mietpreis_NachBaujahr_Zusammengef%C3%BChrt.csv', header=1)

Mietpreise_raw.head()
# Out:
#    Jahr  Kanton  Durch-schnittlicher Mietpreis   \
# 0  2022  Zürich                            1654
# 1  2022    Bern                            1259
# 2  2022  Luzern                            1411
# 3  2022     Uri                            1222
# 4  2022  Schwyz                            1616
#
#    Vertrauens-intervall : \n± (in Fr.)
# 0                                    8
# 1                                    8
# 2                                    9
# 3                                   43
# 4                                   29

# %% [markdown]
# Spalte Kanton an erste Stelle setzen, Vertrauensintervall löschen

# %%
cols = Mietpreise_raw.columns.tolist()
cols = [cols[1]] + [col for col in cols if col != cols[1]]
df = Mietpreise_raw[cols]

Mietpreise_merge = df.drop(df.columns[-1], axis=1)

Mietpreise_merge.head()
# Out:
#    Kanton  Jahr  Durch-schnittlicher Mietpreis
# 0  Zürich  2022                            1654
# 1    Bern  2022                            1259
# 2  Luzern  2022                            1411
# 3     Uri  2022                            1222
# 4  Schwyz  2022                            1616

# %%
Mietpreise_merge.iloc[:, 2] = Mietpreise_merge.iloc[:, 2].astype(float)
Mietpreise_merge.head()
# Out:
#    Kanton  Jahr  Durch-schnittlicher Mietpreis
# 0  Zürich  2022                          1654.0
# 1    Bern  2022                          1259.0
# 2  Luzern  2022                          1411.0
# 3     Uri  2022                          1222.0
# 4  Schwyz  2022                          1616.0

# %% [markdown]
# Import der Leerwohnungziffer-Daten

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline


df = pd.read_csv('https://raw.githubusercontent.com/GRUPPE-BINA24/Datenspeicher/main/Leerwohnungsziffer_Kantone.csv', header=0)

Leerwohnungsziffer=df

Leerwohnungsziffer.head()
# Out:
#                     Kanton 1995 1996  1997  1998  1999  2000  2001  2002  \
# 0            Kanton Aargau  ...  ...  2.17  2.38  2.20  2.13  1.83  1.39
# 1   Kanton Appenzell I.Rh.  ...  ...  1.81  1.91  1.74  2.17  1.90  1.65
# 2   Kanton Appenzell A.Rh.  ...  ...  1.10  1.30  1.62  1.92  2.04  1.94
# 3              Kanton Bern  ...  ...  1.40  1.51  1.46  1.42  1.35  1.12
# 4  Kanton Basel-Landschaft  ...  ...  0.57  0.57  0.58  0.59  0.57  0.42
#
#    2003  ...  2014  2015  2016  2017  2018  2019  2020  2021  2022  2023
# 0  1.16  ...  1.67  1.98  2.18  2.34  2.65  2.59  2.65  2.10  1.69  1.40
# 1  1.39  ...  1.12  0.83  3.63  2.36  1.89  2.02  2.15  2.59  1.67  1.59
# 2  2.03  ...  1.81  1.96  1.99  2.02  2.18  2.30  1.64  2.05  1.84  1.20
# 3  1.08  ...  1.44  1.47  1.69  1.84  1.83  1.87  1.86  1.61  1.48  1.33
# 4  0.42  ...  0.32  0.39  0.47  0.58  0.76  1.06  1.14  0.97  0.93  0.92
#
# [5 rows x 30 columns]

# %% [markdown]
# Spalten bis 2010 und Spalte 2023 löschen

# %%
columns_to_drop = Leerwohnungsziffer.columns[1:16].tolist() + [Leerwohnungsziffer.columns[29]]
Leerwohnungsziffer_bearb = Leerwohnungsziffer.drop(columns_to_drop, axis=1)

Leerwohnungsziffer_bearb.head()
# Out:
#                     Kanton  2010  2011  2012  2013  2014  2015  2016  2017  \
# 0            Kanton Aargau  1.51  1.54  1.61  1.68  1.67  1.98  2.18  2.34
# 1   Kanton Appenzell I.Rh.  1.08  0.72  0.86  1.21  1.12  0.83  3.63  2.36
# 2   Kanton Appenzell A.Rh.  1.22  1.99  1.67  1.68  1.81  1.96  1.99  2.02
# 3              Kanton Bern  1.18  1.26  1.25  1.31  1.44  1.47  1.69  1.84
# 4  Kanton Basel-Landschaft  0.46  0.44  0.44  0.37  0.32  0.39  0.47  0.58
#
#    2018  2019  2020  2021  2022
# 0  2.65  2.59  2.65  2.10  1.69
# 1  1.89  2.02  2.15  2.59  1.67
# 2  2.18  2.30  1.64  2.05  1.84
# 3  1.83  1.87  1.86  1.61  1.48
# 4  0.76  1.06  1.14  0.97  0.93

# %% [markdown]
# Matrix in eine Liste umwandeln

# %%
Leerwohnungziffer_merge = Leerwohnungsziffer_bearb.melt(id_vars=['Kanton'], var_name='Jahr', value_name='Wert')
Leerwohnungziffer_merge.head()
# Out:
#                     Kanton  Jahr  Wert
# 0            Kanton Aargau  2010  1.51
# 1   Kanton Appenzell I.Rh.  2010  1.08
# 2   Kanton Appenzell A.Rh.  2010  1.22
# 3              Kanton Bern  2010  1.18
# 4  Kanton Basel-Landschaft  2010  0.46

# %% [markdown]
# Mergen der Leerwohnungziffern und Mietpreise

# %%
merged_df = pd.concat([Leerwohnungziffer_merge, Mietpreise_merge], axis=0)
merged_df.head()
# Out:
#                     Kanton  Jahr  Wert  Kanton  Durch-schnittlicher Mietpreis
# 0            Kanton Aargau  2010  1.51     NaN                             NaN
# 1   Kanton Appenzell I.Rh.  2010  1.08     NaN                             NaN
# 2   Kanton Appenzell A.Rh.  2010  1.22     NaN                             NaN
# 3              Kanton Bern  2010  1.18     NaN                             NaN
# 4  Kanton Basel-Landschaft  2010  0.46     NaN                             NaN
