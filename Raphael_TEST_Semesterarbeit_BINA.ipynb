# %% [markdown]
# <a href="https://colab.research.google.com/github/GRUPPE-BINA24/Datenspeicher/blob/main/Raphael_TEST_Semesterarbeit_BINA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Hier werden die Daten von Github eingelesen

# %%
# Beispiel-DataFrame, ersetzen Sie dies durch Ihren echten DataFrame
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

Dataset = ("https://raw.githubusercontent.com/GRUPPE-BINA24/Datenspeicher/main/Mietpreis_BERR.xlsx")
df.head()
# Out:
#              Kanton  2022  2021  2020  2019  2018  2017  2016  2015  2014  \
# 0            Aargau  15.9  15.8  15.7  15.5  15.6  15.1  15.1  15.0  15.5
# 1   Appenzell A.Rh.  13.8  14.0  13.9  13.4  12.8  12.8  12.6  13.0  13.1
# 2   Appenzell I.Rh.  15.9  15.2  14.0  15.7  14.4  15.0  13.2  12.9  14.1
# 3  Basel-Landschaft  17.4  17.3  17.2  17.0  16.9  16.7  16.3  16.3  17.0
# 4       Basel-Stadt  18.2  18.0  17.7  17.7  17.4  16.8  16.9  16.4  16.8
#
#    2013  2012
# 0  15.5  15.2
# 1  12.9  12.9
# 2  13.7  13.9
# 3  16.5  16.9
# 4  16.7  16.6

# %%
df = pd.DataFrame({
    'Kategorie': ['Apfel', 'Banane', 'Orange', 'Traube', 'Melone', 'Kiwi', 'Erdbeere', 'Himbeere', 'Kirsche', 'Pfirsich'],
    'Y': [5, 3, 8, 12, 7, 9, 3, 10, 5, 8]
})

# Erstellen des Scatterplots
plt.figure(figsize=[10,6])
plt.scatter(df['Kategorie'], df['Y'])  # 'Kategorie' ist die Spalte mit Wörtern
plt.title('Scatterplot von Kategorien gegen Y-Werte')
plt.xlabel('Kategorie')
plt.ylabel('Y-Werte')
plt.xticks(rotation=45)  # Drehen der Kategorie-Namen, um Überlappung zu vermeiden
plt.show()
